# %%
import os
import pandas as pd
from sqlalchemy import text
from reportlab.lib import colors
from reportlab.lib.pagesizes import A4, A3, landscape, portrait
from reportlab.platypus import SimpleDocTemplate, Table, TableStyle, Paragraph, Spacer
from reportlab.lib.styles import ParagraphStyle, getSampleStyleSheet
from reportlab.pdfbase import pdfmetrics
from reportlab.pdfbase.ttfonts import TTFont
from reportlab.platypus import Paragraph
from reportlab.lib.enums import TA_CENTER
from datetime import datetime
import logging
from config_cloud import *

# %%
# %cd ..
# Out:
# c:\Sanju\Report Automation

# %%
os.getcwd()
# Out:
# 'c:\\Sanju\\Report Automation'

# %%
logging.basicConfig(
    filename=os.path.join(LOG_DIR, "test.log"),
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

# %%
def test_connection():
    logging.info("===== Database Connection Test Started =====")

    try:
        connection = engine.connect()
        logging.info("Database connection established successfully!")
        print("✅ Connected to database successfully!")

        return connection  # Return live DB connection object

    except Exception as e:
        logging.error(f"❌ Database connection failed: {e}")
        print(f"❌ Failed to connect: {e}")
        return None

# %%
conn = test_connection()
# Out:
# ✅ Connected to database successfully!

# %%
sql = "SELECT * FROM defaultdb.public.staging_grievance"

with engine.connect() as connection:
    df = pd.read_sql(sql, connection)

df.head()
# Out:
#   closed_month   month escalated_month  sr_no            grievance_id  \
# 0           --  Jan'23          Jan'23      1  CHMS/CMO/0007/2324/FEE
# 1           --  Apr'23          Apr'23      2   PLN/PLD/0036/2324/FEE
# 2           --  May'23          May'23      3  CHMS/CMO/0069/2324/FEE
# 3       Apr'24  Jun'23          Jun'23      4  CHMS/CMO/0013/2324/FEE
# 4           --  Jul'23          Jul'23      5  CHMS/CMO/0010/2324/FEE
#
#                                           department                   office  \
# 0           Community & Rural Development Department  Chief Minister's Office
# 1  Planning, Investment Promotion and Sustainable...      Planning Department
# 2  Planning, Investment Promotion and Sustainable...  Chief Minister's Office
# 3                       Chief Minister's Secretariat  Chief Minister's Office
# 4                       Chief Minister's Secretariat  Chief Minister's Office
#
# ...
