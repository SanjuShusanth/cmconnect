# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#    ----- ---------------------------------- 1.6/11.0 MB 4.4 MB/s eta 0:00:03
#    ------- -------------------------------- 2.1/11.0 MB 4.5 MB/s eta 0:00:02
#    ------------ --------------------------- 3.4/11.0 MB 4.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.5/11.0 MB 4.5 MB/s eta 0:00:02
#    -------------------- ------------------- 5.5/11.0 MB 4.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.6/11.0 MB 4.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.9/11.0 MB 4.9 MB/s eta 0:00:01
#    -------------------------------- ------- 8.9/11.0 MB 4.9 MB/s eta 0:00:01
#    ------------------------------------- -- 10.2/11.0 MB 5.0 MB/s eta 0:00:01
# ...

# %%
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Sanju\Report Automation\Data\raw files\EPS and CRM Overall RAW Data.xlsx', sheet_name='EPS RAW')
df1 = pd.read_excel(r'C:\Sanju\Report Automation\Data\raw files\EPS and CRM Overall RAW Data.xlsx', sheet_name='CRM RAW')

# %%
df1.count()
# Out:
# Key                    45487
# Week                   45487
# Month                  45487
# Date                   45487
# Entry Date             45487
# Department             35457
# Ticket ID              45487
# Citizen Name           45407
# Citizen ID             45470
# Citizen ID Numb...     28391
# EPS Category           45309
# EPS Type               45374
# District               45457
# Block                  32412
# Location               45436
# Village                28537
# Gender                 45471
# Call Date              45471
# Email                  28864
# Caller Type            45483
# Description            45481
# Communication M...     45487
# Communication M...2      432
# Citizen ID Othe...       304
# Call Mark Categ...     45487
# Priority                1245
# Category Other            33
# Did the call ce...       707
# Was the call ce...       515
# How was your ov...       521
# Are you satisfi...       711
# Would you like ...       706
# ...

# %%
df.head(2)
# Out:
#   Closed Month   Month Escalated Month  Sr No            Grievance ID  \
# 0           --  Jan'23          Jan'23      1  CHMS/CMO/0007/2324/FEE
# 1           --  Apr'23          Apr'23      2   PLN/PLD/0036/2324/FEE
#
#                                           Department                   Office  \
# 0           Community & Rural Development Department  Chief Minister's Office
# 1  Planning, Investment Promotion and Sustainable...      Planning Department
#
#     Complainant Name    Mobile No. ID Type  ...           Source.1 Count  \
# 0    Hafizur Rahaman  9.383319e+09     NaN  ...  Physical Petition     1
# 1  J.V. Lyngdoh (CE)  8.119932e+09     NaN  ...  Physical Petition     1
#
#                Level Updated Resolution Status Avg Closed Days  \
# 0  Directorate Level                   Pending             NaN
# 1  Secretariat Level                   Pending             NaN
#
#   Financial Vs \nAdministrative  \
# 0                     Financial
# ...

# %%
df1.head()
# Out:
#              Key    Week   Month       Date           Entry Date Department  \
# 0  Feb'24 Week 3  Week 3  Feb'24 2024-02-16  2024-02-16 08:02:10        NaN
# 1  Feb'24 Week 3  Week 3  Feb'24 2024-02-16  2024-02-16 08:06:13        NaN
# 2  Feb'24 Week 3  Week 3  Feb'24 2024-02-16  2024-02-16 08:07:48        NaN
# 3  Feb'24 Week 3  Week 3  Feb'24 2024-02-16  2024-02-16 08:09:28        NaN
# 4  Feb'24 Week 3  Week 3  Feb'24 2024-02-16  2024-02-16 08:11:59        NaN
#
#   Ticket ID Citizen Name Citizen ID Citizen ID Numb...  ... Year of Birth  \
# 0         -    Anonymous     Others                NaN  ...           NaN
# 1         -    Anonymous     Others                NaN  ...           NaN
# 2         -    Anonymous     Others                NaN  ...           NaN
# 3         -    Anonymous     Others                NaN  ...           NaN
# 4         -    Anonymous     Others                NaN  ...           NaN
#
#   Alternate Numbe... Communication L... Phone Number  User  \
# ...

# %%
df.columns
# Out:
# Index(['Closed Month', 'Month', 'Escalated Month', 'Sr No', 'Grievance ID',
#        'Department', 'Office', 'Complainant Name', 'Mobile No.', 'ID Type',
#        'ID Name', 'ID Number', 'Email Address (If Available)', 'Category',
#        'Type', 'Feedback/Complaint Description', 'District', 'Block',
#        'Village', 'CM  Instruction', 'Priority', 'Date of Complaint', '`',
#        'Ticket Currently Pending with',
#        'Ticket Currently Pending with(office/department)',
#        'Date of Last Ticket Escalation', 'Status', 'Close Date', 'Source',
#        'Complaint Escalated Date', 'Pendency in Days', 'Pendency Slab',
#        'Month (Reg)', 'Month (Closed)', 'Mode', 'New Department',
#        'New Category', 'New Sub Category', 'Source.1', 'Count', 'Level',
#        'Updated Resolution Status', 'Avg Closed Days',
#        'Financial Vs \nAdministrative',
#        'Intervention of Planning/Finance department required',
# ...

# %%
df1.columns
# Out:
# Index(['Key', 'Week', 'Month', 'Date', 'Entry Date', 'Department', 'Ticket ID',
#        'Citizen Name', 'Citizen ID', 'Citizen ID Numb...', 'EPS Category',
#        'EPS Type', 'District', 'Block', 'Location', 'Village', 'Gender',
#        'Call Date', 'Email', 'Caller Type', 'Description',
#        'Communication M...', 'Communication M...2', 'Citizen ID Othe...',
#        'Call Mark Categ...', 'Priority', 'Category Other',
#        'Did the call ce...', 'Was the call ce...', 'How was your ov...',
#        'Are you satisfi...', 'Would you like ...', 'Suggestion Rema...',
#        'Ticket Status', 'Grievance Categ...', 'Grievance Sub-C...',
#        'Year of Birth', 'Alternate Numbe...', 'Communication L...',
#        'Phone Number', 'User', 'Agent Name', 'Inbound and Out...', 'Call Type',
#        'Scheme', 'VDV Number'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip().str.replace(r'\s+', '_', regex=True).str.replace(r'[^\w]', '', regex=True).str.lower()
df1.columns = df1.columns.str.strip().str.replace(r'\s+', '_', regex=True).str.replace(r'[^\w]', '', regex=True).str.lower()

# %%
df = df.rename(columns={'source': 'source_primary', 'source1': 'source_secondary'})

# %%
df = df.rename(columns={'': 'officer_name'})

# %%
df.columns
# Out:
# Index(['closed_month', 'month', 'escalated_month', 'sr_no', 'grievance_id',
#        'department', 'office', 'complainant_name', 'mobile_no', 'id_type',
#        'id_name', 'id_number', 'email_address_if_available', 'category',
#        'type', 'feedbackcomplaint_description', 'district', 'block', 'village',
#        'cm_instruction', 'priority', 'date_of_complaint', 'officer_name',
#        'ticket_currently_pending_with',
#        'ticket_currently_pending_withofficedepartment',
#        'date_of_last_ticket_escalation', 'status', 'close_date',
#        'source_primary', 'complaint_escalated_date', 'pendency_in_days',
#        'pendency_slab', 'month_reg', 'month_closed', 'mode', 'new_department',
#        'new_category', 'new_sub_category', 'source_secondary', 'count',
#        'level', 'updated_resolution_status', 'avg_closed_days',
#        'financial_vs_administrative',
#        'intervention_of_planningfinance_department_required', 'categorization',
# ...

# %%
df1.columns
# Out:
# Index(['key', 'week', 'month', 'date', 'entry_date', 'department', 'ticket_id',
#        'citizen_name', 'citizen_id', 'citizen_id_numb', 'eps_category',
#        'eps_type', 'district', 'block', 'location', 'village', 'gender',
#        'call_date', 'email', 'caller_type', 'description', 'communication_m',
#        'communication_m2', 'citizen_id_othe', 'call_mark_categ', 'priority',
#        'category_other', 'did_the_call_ce', 'was_the_call_ce',
#        'how_was_your_ov', 'are_you_satisfi', 'would_you_like_',
#        'suggestion_rema', 'ticket_status', 'grievance_categ', 'grievance_subc',
#        'year_of_birth', 'alternate_numbe', 'communication_l', 'phone_number',
#        'user', 'agent_name', 'inbound_and_out', 'call_type', 'scheme',
#        'vdv_number'],
#       dtype='object')

# %%
df.dtypes
# Out:
# closed_month                                                   object
# month                                                          object
# escalated_month                                                object
# sr_no                                                           int64
# grievance_id                                                   object
# department                                                     object
# office                                                         object
# complainant_name                                               object
# mobile_no                                                     float64
# id_type                                                        object
# id_name                                                        object
# id_number                                                      object
# email_address_if_available                                     object
# ...

# %%
print(df1.columns.tolist())
# Out:
# ['key', 'week', 'month', 'date', 'entry_date', 'department', 'ticket_id', 'citizen_name', 'citizen_id', 'citizen_id_numb', 'eps_category', 'eps_type', 'district', 'block', 'location', 'village', 'gender', 'call_date', 'email', 'caller_type', 'description', 'communication_m', 'communication_m2', 'citizen_id_othe', 'call_mark_categ', 'priority', 'category_other', 'did_the_call_ce', 'was_the_call_ce', 'how_was_your_ov', 'are_you_satisfi', 'would_you_like_', 'suggestion_rema', 'ticket_status', 'grievance_categ', 'grievance_subc', 'year_of_birth', 'alternate_numbe', 'communication_l', 'phone_number', 'user', 'agent_name', 'inbound_and_out', 'call_type', 'scheme', 'vdv_number']

# %%
print(df1.columns.tolist())
# Out:
# ['key', 'week', 'month', 'date', 'entry_date', 'department', 'ticket_id', 'citizen_name', 'citizen_id', 'citizen_id_numb', 'eps_category', 'eps_type', 'district', 'block', 'location', 'village', 'gender', 'call_date', 'email', 'caller_type', 'description', 'communication_m', 'communication_m2', 'citizen_id_othe', 'call_mark_categ', 'priority', 'category_other', 'did_the_call_ce', 'was_the_call_ce', 'how_was_your_ov', 'are_you_satisfi', 'would_you_like_', 'suggestion_rema', 'ticket_status', 'grievance_categ', 'grievance_subc', 'year_of_birth', 'alternate_numbe', 'communication_l', 'phone_number', 'user', 'agent_name', 'inbound_and_out', 'call_type', 'scheme', 'vdv_number']

# %%
pip install sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ----------------------------- ---------- 1.6/2.1 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 5.0 MB/s  0:00:00
# ...
#
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
# ...

# %%
# !pip install psycopg2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ----------- ---------------------------- 0.8/2.7 MB 3.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.6/2.7 MB 3.2 MB/s eta 0:00:01
#    -------------------------------------- - 2.6/2.7 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 3.8 MB/s  0:00:00
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\cm_co\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine

# Example for PostgreSQL
engine = create_engine('postgresql://avnadmin:AVNS_0RqM2QO8lu8nstmTVzW@cmconnect2025-26-sanjushusanth-a5cb.i.aivencloud.com:11350/defaultdb')

df.to_sql('staging_grievance', engine, if_exists='replace', index=False)
df1.to_sql('CRM_RAW', engine, if_exists='replace', index=False)
# Out:
# 47
